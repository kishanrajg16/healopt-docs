# %%
import pandas as pd
pd.set_option("display.max_columns", None)
import numpy as np
import random
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Appto_Healthcare\Main_Datasets\Patient_Data_Generated.csv")
df.head()
# Out:
#   patient_id  patient_age patient_gender pref_day pref_time consulting_date  \
# 0      OIGYV           75              M  Tuesday  19:00:00      2019-01-01
# 1      O35C2           27              M   Sunday  18:00:00      2019-01-01
# 2      X62IX           38              M  Tuesday  19:00:00      2019-01-02
# 3      7RCSX           94              M   Sunday  16:00:00      2019-01-02
# 4      3KIPU           70              F   Sunday  22:00:00      2019-01-02
#
#   consulting_time consulting_day consulting_timestamp
# 0        03:58:31        Tuesday  2019-01-01 03:58:31
# 1        15:38:30        Tuesday  2019-01-01 15:38:30
# 2        02:27:11      Wednesday  2019-01-02 02:27:11
# 3        05:13:50      Wednesday  2019-01-02 05:13:50
# 4        05:18:12      Wednesday  2019-01-02 05:18:12

# %%
df.shape
# Out:
# (3211537, 9)

# %%
df['patient_id'].nunique()
# Out:
# 3211537

# %%
doctor_spec = pd.read_csv(r"D:\Appto_Healthcare\Cleaned_Datasets\final_doctor_data_11l.csv")
doctor_spec.head()
# Out:
#           npi            physician_name gender                pri_spec  \
# 0  1225111404  DAVIDA RUTRICK-GOLDSTEIN      F  CLINICAL SOCIAL WORKER
# 1  1225170988             STEVEN GREENE      M             DERMATOLOGY
# 2  1225184278            MICHAEL MORGAN      M        PHYSICAL THERAPY
# 3  1225216302                JOHN SCOTT      M        PHYSICAL THERAPY
# 4  1225199664            ALEXIS SELWOOD      F  CLINICAL SOCIAL WORKER
#
#   is_affltd      hosp_affln  rating  patients  experience  avg_wttime  \
# 0         N  NO AFFILIATION    6.73      7383          42          27
# 1         N  NO AFFILIATION    6.66      9278          41          15
# 2         N  NO AFFILIATION    6.14      7032          28          11
# 3         N  NO AFFILIATION    7.50     11340          31          17
# 4         N  NO AFFILIATION    8.92      7746          41          10
#
#    busy_index        shift_1        shift_2 emergency_avail  \
# ...

# %%
doctor_spec.columns
# Out:
# Index(['npi', 'physician_name', 'gender', 'pri_spec', 'is_affltd',
#        'hosp_affln', 'rating', 'patients', 'experience', 'avg_wttime',
#        'busy_index', 'shift_1', 'shift_2', 'emergency_avail', 'street', 'city',
#        'state', 'state_code', 'zip'],
#       dtype='object')

# %%
doctor_spec['pri_spec'].value_counts()
# Out:
# NURSE PRACTITIONER                        159464
# INTERNAL MEDICINE                          91239
# FAMILY MEDICINE                            87096
# PHYSICIAN ASSISTANT                        82166
# PHYSICAL THERAPY                           62389
#                                            ...
# PERIPHERAL VASCULAR DISEASE                   55
# ADULT CONGENITAL HEART DISEASE (ACHD)         37
# MEDICAL TOXICOLOGY                            36
# UNDEFINED NON-PHYSICIAN TYPE (SPECIFY)        19
# MASS IMMUNIZATION ROSTER BILLER                4
# Name: pri_spec, Length: 86, dtype: int64

# %%
def generate_treatments(size) -> list:
    treatments = doctor_spec['pri_spec'].tolist()

    # likelihood of each of the treatments - make some more common
    weights = random.choices(range(1, 100), k=len(treatments))
    treatment_codes = random.choices(
        treatments, k=size, weights=weights)
    return treatment_codes

# %%
len(doctor_spec)
# Out:
# 1163422

# %%
df['npi']=np.random.choice(doctor_spec['npi'],size=len(df))
df.head()
# Out:
#   patient_id  patient_age patient_gender pref_day pref_time consulting_date  \
# 0      OIGYV           75              M  Tuesday  19:00:00      2019-01-01
# 1      O35C2           27              M   Sunday  18:00:00      2019-01-01
# 2      X62IX           38              M  Tuesday  19:00:00      2019-01-02
# 3      7RCSX           94              M   Sunday  16:00:00      2019-01-02
# 4      3KIPU           70              F   Sunday  22:00:00      2019-01-02
#
#   consulting_time consulting_day consulting_timestamp         npi
# 0        03:58:31        Tuesday  2019-01-01 03:58:31  1205361326
# 1        15:38:30        Tuesday  2019-01-01 15:38:30  1740673250
# 2        02:27:11      Wednesday  2019-01-02 02:27:11  1639185044
# 3        05:13:50      Wednesday  2019-01-02 05:13:50  1821261405
# 4        05:18:12      Wednesday  2019-01-02 05:18:12  1831337682

# %%
df.nunique()
# Out:
# patient_id              3211537
# patient_age                  87
# patient_gender                3
# pref_day                      7
# pref_time                    15
# consulting_date             707
# consulting_time           86400
# consulting_day                7
# consulting_timestamp    3119934
# npi                     1089829
# dtype: int64

# %%
dk = df.drop_duplicates(subset=['patient_id'],keep='first',inplace=False)

# %%
dk.shape
# Out:
# (3211537, 10)

# %%
dk = dk.join(doctor_spec.set_index('npi'), on='npi')

# %%
dk.head()
# Out:
#   patient_id  patient_age patient_gender pref_day pref_time consulting_date  \
# 0      OIGYV           75              M  Tuesday  19:00:00      2019-01-01
# 1      O35C2           27              M   Sunday  18:00:00      2019-01-01
# 2      X62IX           38              M  Tuesday  19:00:00      2019-01-02
# 3      7RCSX           94              M   Sunday  16:00:00      2019-01-02
# 4      3KIPU           70              F   Sunday  22:00:00      2019-01-02
#
#   consulting_time consulting_day consulting_timestamp         npi  \
# 0        03:58:31        Tuesday  2019-01-01 03:58:31  1205361326
# 1        15:38:30        Tuesday  2019-01-01 15:38:30  1740673250
# 2        02:27:11      Wednesday  2019-01-02 02:27:11  1639185044
# 3        05:13:50      Wednesday  2019-01-02 05:13:50  1821261405
# 4        05:18:12      Wednesday  2019-01-02 05:18:12  1831337682
#
#                physician_name gender              pri_spec is_affltd  \
# ...

# %%
dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3211537 entries, 0 to 3211536
# Data columns (total 28 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   patient_id            object
#  1   patient_age           int64
#  2   patient_gender        object
#  3   pref_day              object
#  4   pref_time             object
#  5   consulting_date       object
#  6   consulting_time       object
#  7   consulting_day        object
#  8   consulting_timestamp  object
#  9   npi                   int64
#  10  physician_name        object
#  11  gender                object
#  12  pri_spec              object
#  13  is_affltd             object
#  14  hosp_affln            object
#  15  rating                float64
#  16  patients              int64
#  17  experience            int64
#  18  avg_wttime            int64
#  19  busy_index            int64
#  20  shift_1               object
#  21  shift_2               object
# ...

# %%
dk.columns
# Out:
# Index(['patient_id', 'patient_age', 'patient_gender', 'pref_day', 'pref_time',
#        'consulting_date', 'consulting_time', 'consulting_day',
#        'consulting_timestamp', 'npi', 'physician_name', 'gender', 'pri_spec',
#        'is_affltd', 'hosp_affln', 'rating', 'patients', 'experience',
#        'avg_wttime', 'busy_index', 'shift_1', 'shift_2', 'emergency_avail',
#        'street', 'city', 'state', 'state_code', 'zip'],
#       dtype='object')

# %%
dk['pri_spec'].value_counts()
# Out:
# NURSE PRACTITIONER                        439861
# INTERNAL MEDICINE                         251481
# FAMILY MEDICINE                           240155
# PHYSICIAN ASSISTANT                       226678
# PHYSICAL THERAPY                          172399
#                                            ...
# PERIPHERAL VASCULAR DISEASE                  147
# ADULT CONGENITAL HEART DISEASE (ACHD)        107
# MEDICAL TOXICOLOGY                            95
# UNDEFINED NON-PHYSICIAN TYPE (SPECIFY)        61
# MASS IMMUNIZATION ROSTER BILLER                5
# Name: pri_spec, Length: 86, dtype: int64

# %%
dk = dk.drop(['physician_name', 'gender','is_affltd', 'hosp_affln', 'rating', 'patients', 'experience',
       'avg_wttime', 'busy_index', 'shift_1', 'shift_2', 'emergency_avail',
       'street', 'hosp_affln', 'rating', 'patients', 'experience'], axis = 1)
dk.head()
# Out:
#   patient_id  patient_age patient_gender pref_day pref_time consulting_date  \
# 0      OIGYV           75              M  Tuesday  19:00:00      2019-01-01
# 1      O35C2           27              M   Sunday  18:00:00      2019-01-01
# 2      X62IX           38              M  Tuesday  19:00:00      2019-01-02
# 3      7RCSX           94              M   Sunday  16:00:00      2019-01-02
# 4      3KIPU           70              F   Sunday  22:00:00      2019-01-02
#
#   consulting_time consulting_day consulting_timestamp         npi  \
# 0        03:58:31        Tuesday  2019-01-01 03:58:31  1205361326
# 1        15:38:30        Tuesday  2019-01-01 15:38:30  1740673250
# 2        02:27:11      Wednesday  2019-01-02 02:27:11  1639185044
# 3        05:13:50      Wednesday  2019-01-02 05:13:50  1821261405
# 4        05:18:12      Wednesday  2019-01-02 05:18:12  1831337682
#
#                pri_spec          city       state state_code    zip
# ...

# %%
dk['pref_day'] = dk['pref_day'].str.upper()
dk['consulting_day'] = dk['consulting_day'].str.upper()
dk.head()
# Out:
#   patient_id  patient_age patient_gender pref_day pref_time consulting_date  \
# 0      OIGYV           75              M  TUESDAY  19:00:00      2019-01-01
# 1      O35C2           27              M   SUNDAY  18:00:00      2019-01-01
# 2      X62IX           38              M  TUESDAY  19:00:00      2019-01-02
# 3      7RCSX           94              M   SUNDAY  16:00:00      2019-01-02
# 4      3KIPU           70              F   SUNDAY  22:00:00      2019-01-02
#
#   consulting_time consulting_day consulting_timestamp         npi  \
# 0        03:58:31        TUESDAY  2019-01-01 03:58:31  1205361326
# 1        15:38:30        TUESDAY  2019-01-01 15:38:30  1740673250
# 2        02:27:11      WEDNESDAY  2019-01-02 02:27:11  1639185044
# 3        05:13:50      WEDNESDAY  2019-01-02 05:13:50  1821261405
# 4        05:18:12      WEDNESDAY  2019-01-02 05:18:12  1831337682
#
#                pri_spec          city       state state_code    zip
# ...

# %%
# dk['doctor_specialization'] = list(map(lambda x: x.capitalize(), dk['doctor_specialization']))
# dk['city'] = list(map(lambda x: x.capitalize(), dk['city']))

# %%
dk.shape
# Out:
# (3211537, 15)

# %%
patient_data = dk

# %%
patient_data['zip'] = patient_data['zip'].astype(str)

# %%
patient_data['consulting_timestamp'] = pd.to_datetime(patient_data['consulting_timestamp'])

# %%
patient_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3211537 entries, 0 to 3211536
# Data columns (total 15 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   patient_id            object
#  1   patient_age           int64
#  2   patient_gender        object
#  3   pref_day              object
#  4   pref_time             object
#  5   consulting_date       object
#  6   consulting_time       object
#  7   consulting_day        object
#  8   consulting_timestamp  datetime64[ns]
#  9   npi                   int64
#  10  pri_spec              object
#  11  city                  object
#  12  state                 object
#  13  state_code            object
#  14  zip                   object
# dtypes: datetime64[ns](1), int64(2), object(12)
# memory usage: 392.0+ MB

# %%
patient_data.head()
# Out:
#   patient_id  patient_age patient_gender pref_day pref_time consulting_date  \
# 0      OIGYV           75              M  TUESDAY  19:00:00      2019-01-01
# 1      O35C2           27              M   SUNDAY  18:00:00      2019-01-01
# 2      X62IX           38              M  TUESDAY  19:00:00      2019-01-02
# 3      7RCSX           94              M   SUNDAY  16:00:00      2019-01-02
# 4      3KIPU           70              F   SUNDAY  22:00:00      2019-01-02
#
#   consulting_time consulting_day consulting_timestamp         npi  \
# 0        03:58:31        TUESDAY  2019-01-01 03:58:31  1205361326
# 1        15:38:30        TUESDAY  2019-01-01 15:38:30  1740673250
# 2        02:27:11      WEDNESDAY  2019-01-02 02:27:11  1639185044
# 3        05:13:50      WEDNESDAY  2019-01-02 05:13:50  1821261405
# 4        05:18:12      WEDNESDAY  2019-01-02 05:18:12  1831337682
#
#                pri_spec          city       state state_code    zip
# ...

# %%
patient_data.to_csv(r"D:\Appto_Healthcare\Cleaned_Datasets\final_manipulated_patient_data_33l.csv",index=False)

# %%
from sqlalchemy import create_engine
import psycopg2 
import io

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/demodb')

# %%
patient_data.head(0).to_sql('patient_table', engine, if_exists='replace',index=False)

# %%
conn = engine.raw_connection()
cur = conn.cursor()
output = io.StringIO()
patient_data.to_csv(output, sep='\t', header=False, index=False)
output.seek(0)
contents = output.getvalue()
cur.copy_from(output, 'patient_table', null="") # null values become ''
conn.commit()
